# %%
import sys
import torch

print('Python executable :', sys.executable)
print('PyTorch version   :', torch.__version__)
print('PyTorch CUDA      :', torch.version.cuda)
print('CUDA available    :', torch.cuda.is_available())
# Out:
# Python executable : c:\ai_challingers\recycling_ssg\.venv\Scripts\python.exe
# PyTorch version   : 2.11.0+cu128
# PyTorch CUDA      : 12.8
# CUDA available    : True

# %%
import sys
import time
import torch

print("Python:", sys.executable)
print("Torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

start = time.time()
x = torch.randn(3000, 3000, device="cuda")
y = x @ x
torch.cuda.synchronize()

print(f"GPU test: {time.time() - start:.3f}s")
# Out:
# Python: c:\ai_challingers\recycling_ssg\.venv\Scripts\python.exe
# Torch: 2.11.0+cu128
# CUDA: 12.8
# CUDA available: True
# GPU: NVIDIA RTX 1000 Ada Generation Laptop GPU
# GPU test: 0.225s

# %%
import time
from ultralytics import YOLO

start = time.time()
model = YOLO("yolo11n.pt")
print(f"YOLO load: {time.time() - start:.2f}s")
# Out:
# YOLO load: 0.05s
